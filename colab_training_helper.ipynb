# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import os
project_path = r"/content/drive/MyDrive/vision_transformer"
os.chdir(project_path)

# %%
! ls
# Out:
# colab_training_helper.ipynb  __pycache__		  utils.py
# layers			     runs			  vit_config.yaml
# model_weights		     train_vision_transformer.py  vit.py

# %%
! nvidia-smi
# Out:
# Wed Dec 14 07:01:54 2022
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 460.32.03    Driver Version: 460.32.03    CUDA Version: 11.2     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   45C    P0    25W /  70W |      0MiB / 15109MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
! cat vit_config.yaml
# Out:
# model_architecture:
#     image_size: [32, 32, 3]
#     patch_size: 2
#     patch_embedding_dim: 512
#     num_attention_heads: 8
#     num_transformer_encoder: 6
#     mlp_units: 512
#     dropout_rate: 0.1
#     model_name: cifar_viT
#
#
# training_settings:
#     epochs: 120
#     batch_size: 64
#     learning_rate: 0.0002
#     save_plots: True
#     show_plots: False
#
# save_paths:
#     model_save_path: model_weights
#     plot_save_path: runs

# %%
! python train_vision_transformer.py
# Out:
# Streaming output truncated to the last 5000 lines.
# Batch [189|782] Batch loss: 1.0271203517913818, batch accuracy: 0.671875
# Batch [190|782] Batch loss: 0.894260048866272, batch accuracy: 0.734375
# Batch [191|782] Batch loss: 1.177290439605713, batch accuracy: 0.5625
# Batch [192|782] Batch loss: 0.8551814556121826, batch accuracy: 0.65625
# Batch [193|782] Batch loss: 1.0333561897277832, batch accuracy: 0.640625
# Batch [194|782] Batch loss: 1.2462496757507324, batch accuracy: 0.5625
# Batch [195|782] Batch loss: 1.2844997644424438, batch accuracy: 0.609375
# Batch [196|782] Batch loss: 0.8556917905807495, batch accuracy: 0.734375
# Batch [197|782] Batch loss: 0.8096705675125122, batch accuracy: 0.71875
# Batch [198|782] Batch loss: 0.8919925689697266, batch accuracy: 0.671875
# Batch [199|782] Batch loss: 0.9993413686752319, batch accuracy: 0.65625
# Batch [200|782] Batch loss: 1.0685597658157349, batch accuracy: 0.625
# ...
